# %%
col_vec1= np.zeros( (100, 4) )
col_vec1[:, 1]= np.linspace(0.1, 1, 100)
col_vec1[:, 3]= 1

col_vec2= np.zeros( (100, 4) )
col_vec2[:, 0]= np.linspace(0.1, 1, 100)
col_vec2[:, 1]= col_vec2[:, 0]*165/255
col_vec2[:, 3]= 1

col_map1 = ListedColormap(col_vec1)
col_map2 = ListedColormap(col_vec2)
cms=[ col_map1, col_map2]

np.random.seed(19680801)
data = np.random.rand(30, 30)

fig, axs = plt.subplots(1, 2, figsize=(6, 3), constrained_layout=True)
for [ax, cmap] in zip(axs, cms):
    psm = ax.pcolormesh(data, cmap=cmap, rasterized=True, vmin=0, vmax=1)
    fig.colorbar(psm, ax=ax)
plt.show()


np.random.seed(19680801)
data = np.random.rand(30, 30)

fig, axs = plt.subplots(1, 2, figsize=(6, 3), constrained_layout=True)
for [ax, cmap] in zip(axs, cms):
    psm = ax.contourf(data, cmap=cmap, vmin=0, vmax=1)
    fig.colorbar(psm, ax=ax)
plt.show()

# %%
# 32 % of all healthcare-associated infection are urinary tract infections; 
#22 percent are surgical site infections; 15 percent are pneumonia (lung infections); 
#and 14 percent are bloodstream infections” 
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Urinary tract', 'Surgical site', 'lung', 'Bloodstream', 'Other'

sizes = [32, 22, 15, 14, 17]
nums=[1700000*size/100 for size in sizes]
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
#ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# 32 % of all healthcare-associated infection are urinary tract infections; 
#22 percent are surgical site infections; 15 percent are pneumonia (lung infections); 
#and 14 percent are bloodstream infections” 
import matplotlib.pyplot as plt
import numpy as np

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Urinary tract', 'Surgical site', 'lung', 'Bloodstream', 'Other'

sizes = [32, 22, 15, 14, 17]
nums=np.array( [1700000*size/100 for size in sizes] )
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

def absolute_value(val):
    a  = int( val/100.*nums.sum() )
    return  str(a//1000) + 'K'

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct=absolute_value,
        shadow=False, startangle=90 )
#ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
#plt.title('healthcare-associated infections')
plt.rcParams.update({'font.size': 13})
plt.savefig("/home/xiaoling/SpiralWave/PapFig/infection_lung.png", dpi=500)
plt.show()

# %%
#33,269 HAIs among newborns in high-risk nurseries, 
#19,059 among newborns in well-baby nurseries, 
#417,946 among adults and children in ICUs, 
#and 1,266,851 among adults and children outside of ICUs. 

import matplotlib.pyplot as plt
import numpy as np

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'newborns in high-risk nurseries',  'adults and children in ICUs', 'newborns in well-baby nurseries', 'adults and children outside of ICUs'
sizes = [32, 22, 15, 14, 17]
nums=np.array( [33269, 417946, 19059,  1266951] )
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

def absolute_value(val):
    a  = int(val/100.*nums.sum() )
    return str(a//1000) + 'K'

fig1, ax1 = plt.subplots()
ax1.pie(nums, autopct=absolute_value,
        shadow=False, startangle=90)
#ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.rcParams.update({'font.size': 13})
plt.savefig("/home/xiaoling/SpiralWave/PapFig/infection_newborn.png", dpi=500)

plt.show()

# %%
# 32 % of all healthcare-associated infection are urinary tract infections; 
#22 percent are surgical site infections; 15 percent are pneumonia (lung infections); 
#and 14 percent are bloodstream infections” 
import matplotlib.pyplot as plt
import numpy as np

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Urinary tract', 'Surgical site', 'lung', 'Bloodstream', 'Other'

sizes = [32, 22, 15, 14, 17]
nums=np.array( [1700000*size/100 for size in sizes] )
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

def absolute_value(val):
    a  = int(val/100.*nums.sum() )
    return a

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct=absolute_value,
        shadow=True, startangle=90)
#ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
#        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('healthcare-associated infections')

plt.show()
