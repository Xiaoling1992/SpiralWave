# %%
import numpy as np    
import matplotlib.pyplot as plt  
from matplotlib.animation import FuncAnimation 
from matplotlib import cm
from numpy.random import randn
rho= 0.8
plt.figure()
decimation= range(0, 10)
rho_eff= [rho**(2**round) for round in decimation ] 
plt.plot( decimation, rho_eff,  linewidth=3)
    #plt.plot(phis, PeriodSet[k,:], linestyle='-.', linewidth=3, color=ColMap[2,:], marker='o',
    #  markersize=7, label=r'$\rho=$'+str(rhos[k]) )
    #line2,=plt.plot(x,x**1.5, linestyle='-', color=(1,0,0), linewidth=4, marker='^',
    # markerfacecolor='blue', markeredgecolor='r', markersize=12, label='example 2')

#plt.axis([0, 12, 0, 120])
plt.ylim( (-0.05, 1))
plt.xlabel(r'$decimation$', fontsize=16)
plt.ylabel(r'$\rho_{eff}$', fontsize=16)
plt.xticks( fontsize= 14) 
plt.yticks([0.8, 0.8**2, 0.8**4, 0.8**8, 0.8**16  ], (r'$\rho$', r'$\rho^2$', r'$\rho^4$', r'$\rho^8$', r'$\rho^{16}$'), fontsize= 14)

plt.tight_layout()
plt.savefig("/home/xiaoling/SpiralWave/PapFig/Lin_RhoEff-Deci.png", dpi=500)
plt.show()
